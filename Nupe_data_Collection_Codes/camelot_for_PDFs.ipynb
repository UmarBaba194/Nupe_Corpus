# %%
import camelot

# %%
tables=camelot.read_pdf('English-Nupe-Dictionary-Current-Edition-1.pdf')

# %%
tables
# Out:
# <TableList n=0>

# %%
tables=camelot.read_pdf('English-Nupe-Dictionary-Current-Edition-1.pdf',flavor='stream',pages='4-end',skiprows='1')
# Out:
# C:\Users\umb\Anaconda3\lib\site-packages\camelot\parsers\stream.py:365: UserWarning: No tables found in table area 1
#   warnings.warn(f"No tables found in table area {table_idx + 1}")

# %%
tables
# Out:
# <TableList n=183>

# %%
tables[0]
# Out:
# <Table shape=(36, 2)>

# %%
tables[0].df
# Out:
#                                         0                                    1
# 0                Aberration, n., Yězákuṇ.        Able rate, n., Milò jiṇjiṇwǒ.
# 1                        Abet, v., Pagwa.     Able seaman, n., Ndǎdù jiṇjiṇwǒ.
# 2                   Abetting, n., Egwapa.        Able-bodied seaman, n., Ndǎdù
# 3             Abeyance, n., Kaka; Ka èká.                    nạkàṇ-jiṇjiṇwǒci.
# 4                   Abfarad, n., Abufárù.                Abled, adj., Jiṇwǒci.
# 5                   Abhenry, n., Abuhéri.           Ableism, n., Jiṇjiṇwǒwogi.
# 6                        Abhor, v., Ṇàvǒ.             Abloom, adj., Gòfiṇnilá.
# 7                 Abhorrence, n., Niṇàvǒ.           Ablution, n., Yèṇá; Eyěṇá.
# 8                Abhorrent, n., Niṇàvǒci.         Ablution, perform, v., Ṇáyě.
# 9                       Abide, v., Fédạn.             Ably, adv., Jiṇjiṇwǒnyǐ.
# 10                  Abiding, n., Fifédạn.      Abnegate, v., Ṇàmipa; Ṇà emipa.
# 11                   Abidjan, n., Abíjạṇ.              Abnegation, v., Mipaṇà.
# 12   Abietic acid, n., Tsàrìgi tíkàṇcigá.    Abnormal, adj., Ràzhì; Rà zhìzhì.
# 13                  Abigail, n., Abigélì.      Abnormality, n., Zhìrà; Ezhìrà.
# 14     Abiku (spirit child), n., Dzǎṃàgi.  Abnormal loss, n., Gbigbíṇyá ràzhì.
# 15  Abilene principle, n., Tídzò Ábulìnì.      Abnormal profit, n., Elé ràzhì.
# 16                 Ability, n., Jiṇjiṇwǒ.     Abnormal retinal correspondence,
# 17   Ability grouping, n., Nàmi jiṇjiṇwǒ.               n., Fùkà sayéci ràzhì.
# 18       Ability to pay, n., Jiṇjiṇwǒ ṇyá       Abnormal returns, n., Ezhǐnzhí
# 19                                yiyáwǒ.                               ràzhì.
# 20              Ab initio, adv., Càncàbà.                        Abo, n., Abo.
# 21            Abiogenesis, n., Nàkákânmạ.    Aboard, adj., v., Dạnya; Dạn eya.
# 22                  Abiotic, n., Nànạkuṇ.                    Abode, n., Kpòmi.
# 23                       Abir, n., Abéri.                    Abohm, n., Abomù.
# 24               Abitur, n., Wadzùṇcizhì.    Aboiteau, n., Lenjèdù; Lenjè edù.
# 25                 Abject, adj., Nàkpárá.                   Abolish, v., Kòtí.
# 26                     Abjure, v., Zhìbǒ.                Abolition, n., Etíkò.
# 27                  Abkhaz, n., Abukázhì.           Abolitionist, n., Etíkòci.
# 28               Ablation, n., Lilákiávo.          Abomasum, n., Nyèděsákuṇnạ.
# 29                  Ablate, vt., Lákiávo.               A-bomb, n., Nạtiṇgi-A.
# 30             Ablative, n., Lilákiávoci.       Abominable, adj., Nyạdèdèkóci;
# 31                Ablator, n., Zàlákiábo.                        Enyạdèdèkóci.
# 32               Ablaut, n., Wóva; Èwóva.              Abominable Snowman, n.,
# 33               Ablaze, adj., v., Wạṇnạ.                  Ndǎnyạfù Nyạdèdèkó.
# 34                     Able, adj., Jiṇwǒ.         Abominate, n., Là nyạdèdèkó.
# 35   Able-bodied, adj., Nạkàṇ-jiṇjiṇwǒci.

# %%
tables.export('foo.csv',f='csv')

# %%
f=tables[0]

# %%
f.df
# Out:
#                                         0                                    1
# 0                Aberration, n., Yězákuṇ.        Able rate, n., Milò jiṇjiṇwǒ.
# 1                        Abet, v., Pagwa.     Able seaman, n., Ndǎdù jiṇjiṇwǒ.
# 2                   Abetting, n., Egwapa.        Able-bodied seaman, n., Ndǎdù
# 3             Abeyance, n., Kaka; Ka èká.                    nạkàṇ-jiṇjiṇwǒci.
# 4                   Abfarad, n., Abufárù.                Abled, adj., Jiṇwǒci.
# 5                   Abhenry, n., Abuhéri.           Ableism, n., Jiṇjiṇwǒwogi.
# 6                        Abhor, v., Ṇàvǒ.             Abloom, adj., Gòfiṇnilá.
# 7                 Abhorrence, n., Niṇàvǒ.           Ablution, n., Yèṇá; Eyěṇá.
# 8                Abhorrent, n., Niṇàvǒci.         Ablution, perform, v., Ṇáyě.
# 9                       Abide, v., Fédạn.             Ably, adv., Jiṇjiṇwǒnyǐ.
# 10                  Abiding, n., Fifédạn.      Abnegate, v., Ṇàmipa; Ṇà emipa.
# 11                   Abidjan, n., Abíjạṇ.              Abnegation, v., Mipaṇà.
# 12   Abietic acid, n., Tsàrìgi tíkàṇcigá.    Abnormal, adj., Ràzhì; Rà zhìzhì.
# 13                  Abigail, n., Abigélì.      Abnormality, n., Zhìrà; Ezhìrà.
# 14     Abiku (spirit child), n., Dzǎṃàgi.  Abnormal loss, n., Gbigbíṇyá ràzhì.
# 15  Abilene principle, n., Tídzò Ábulìnì.      Abnormal profit, n., Elé ràzhì.
# 16                 Ability, n., Jiṇjiṇwǒ.     Abnormal retinal correspondence,
# 17   Ability grouping, n., Nàmi jiṇjiṇwǒ.               n., Fùkà sayéci ràzhì.
# 18       Ability to pay, n., Jiṇjiṇwǒ ṇyá       Abnormal returns, n., Ezhǐnzhí
# 19                                yiyáwǒ.                               ràzhì.
# 20              Ab initio, adv., Càncàbà.                        Abo, n., Abo.
# 21            Abiogenesis, n., Nàkákânmạ.    Aboard, adj., v., Dạnya; Dạn eya.
# 22                  Abiotic, n., Nànạkuṇ.                    Abode, n., Kpòmi.
# 23                       Abir, n., Abéri.                    Abohm, n., Abomù.
# 24               Abitur, n., Wadzùṇcizhì.    Aboiteau, n., Lenjèdù; Lenjè edù.
# 25                 Abject, adj., Nàkpárá.                   Abolish, v., Kòtí.
# 26                     Abjure, v., Zhìbǒ.                Abolition, n., Etíkò.
# 27                  Abkhaz, n., Abukázhì.           Abolitionist, n., Etíkòci.
# 28               Ablation, n., Lilákiávo.          Abomasum, n., Nyèděsákuṇnạ.
# 29                  Ablate, vt., Lákiávo.               A-bomb, n., Nạtiṇgi-A.
# 30             Ablative, n., Lilákiávoci.       Abominable, adj., Nyạdèdèkóci;
# 31                Ablator, n., Zàlákiábo.                        Enyạdèdèkóci.
# 32               Ablaut, n., Wóva; Èwóva.              Abominable Snowman, n.,
# 33               Ablaze, adj., v., Wạṇnạ.                  Ndǎnyạfù Nyạdèdèkó.
# 34                     Able, adj., Jiṇwǒ.         Abominate, n., Là nyạdèdèkó.
# 35   Able-bodied, adj., Nạkàṇ-jiṇjiṇwǒci.

# %%
First_table=tables[4-186]

# %%
First_table.to_csv('Nupe_Dictionary')

# %%
import pandas as pd
import numpy as np

# %%
tables.columns=['English_translation','Nupe_translation']
print(tables)
# Out:
# <TableList n=1>

# %%
tables[0].df
# Out:
#                                         0                                    1
# 0                Aberration, n., Yězákuṇ.        Able rate, n., Milò jiṇjiṇwǒ.
# 1                        Abet, v., Pagwa.     Able seaman, n., Ndǎdù jiṇjiṇwǒ.
# 2                   Abetting, n., Egwapa.        Able-bodied seaman, n., Ndǎdù
# 3             Abeyance, n., Kaka; Ka èká.                    nạkàṇ-jiṇjiṇwǒci.
# 4                   Abfarad, n., Abufárù.                Abled, adj., Jiṇwǒci.
# 5                   Abhenry, n., Abuhéri.           Ableism, n., Jiṇjiṇwǒwogi.
# 6                        Abhor, v., Ṇàvǒ.             Abloom, adj., Gòfiṇnilá.
# 7                 Abhorrence, n., Niṇàvǒ.           Ablution, n., Yèṇá; Eyěṇá.
# 8                Abhorrent, n., Niṇàvǒci.         Ablution, perform, v., Ṇáyě.
# 9                       Abide, v., Fédạn.             Ably, adv., Jiṇjiṇwǒnyǐ.
# 10                  Abiding, n., Fifédạn.      Abnegate, v., Ṇàmipa; Ṇà emipa.
# 11                   Abidjan, n., Abíjạṇ.              Abnegation, v., Mipaṇà.
# 12   Abietic acid, n., Tsàrìgi tíkàṇcigá.    Abnormal, adj., Ràzhì; Rà zhìzhì.
# 13                  Abigail, n., Abigélì.      Abnormality, n., Zhìrà; Ezhìrà.
# 14     Abiku (spirit child), n., Dzǎṃàgi.  Abnormal loss, n., Gbigbíṇyá ràzhì.
# 15  Abilene principle, n., Tídzò Ábulìnì.      Abnormal profit, n., Elé ràzhì.
# 16                 Ability, n., Jiṇjiṇwǒ.     Abnormal retinal correspondence,
# 17   Ability grouping, n., Nàmi jiṇjiṇwǒ.               n., Fùkà sayéci ràzhì.
# 18       Ability to pay, n., Jiṇjiṇwǒ ṇyá       Abnormal returns, n., Ezhǐnzhí
# 19                                yiyáwǒ.                               ràzhì.
# 20              Ab initio, adv., Càncàbà.                        Abo, n., Abo.
# 21            Abiogenesis, n., Nàkákânmạ.    Aboard, adj., v., Dạnya; Dạn eya.
# 22                  Abiotic, n., Nànạkuṇ.                    Abode, n., Kpòmi.
# 23                       Abir, n., Abéri.                    Abohm, n., Abomù.
# 24               Abitur, n., Wadzùṇcizhì.    Aboiteau, n., Lenjèdù; Lenjè edù.
# 25                 Abject, adj., Nàkpárá.                   Abolish, v., Kòtí.
# 26                     Abjure, v., Zhìbǒ.                Abolition, n., Etíkò.
# 27                  Abkhaz, n., Abukázhì.           Abolitionist, n., Etíkòci.
# 28               Ablation, n., Lilákiávo.          Abomasum, n., Nyèděsákuṇnạ.
# 29                  Ablate, vt., Lákiávo.               A-bomb, n., Nạtiṇgi-A.
# 30             Ablative, n., Lilákiávoci.       Abominable, adj., Nyạdèdèkóci;
# 31                Ablator, n., Zàlákiábo.                        Enyạdèdèkóci.
# 32               Ablaut, n., Wóva; Èwóva.              Abominable Snowman, n.,
# 33               Ablaze, adj., v., Wạṇnạ.                  Ndǎnyạfù Nyạdèdèkó.
# 34                     Able, adj., Jiṇwǒ.         Abominate, n., Là nyạdèdèkó.
# 35   Able-bodied, adj., Nạkàṇ-jiṇjiṇwǒci.

# %%
df.head(30)

# %%
df['Nupe_translation'].str.split(',', expand=True)

# %%
df['English_translation'].str.split(',', expand=True)
