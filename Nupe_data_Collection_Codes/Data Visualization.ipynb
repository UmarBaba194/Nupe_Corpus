# %%
import pandas as pd

# %%
df=pd.read_csv('nupe-engFinal2.csv')

# %%
df['nupe words count']=df['nupe'].str.split().str.len()

# %%
df['eng words count']=df['eng'].str.split().str.len()

# %%
df.head()
# Out:
#                                                  eng  \
# 0  Praise be to Allah the Cherisher and Sustainer...
# 1                        Most Gracious Most Merciful
# 2                      Master of the Day of Judgment
# 3           Thee do we worship and Thine aid we seek
# 4                           Show us the straight way
#
#                                                 nupe  nupe words count  \
# 0  Yebo kpata ajin tabbata ya Soko Etsu nae kpa a...              12.0
# 1  Estu na niimau ke ke yiba to mumini to kafiri ...              26.0
# 2                    Etsu na wun mulki efo egagbaena               6.0
# 3  Wyo gbaogi ga yi-ejin bauta yao be wyo gbaogi ...              13.0
# 4                Soko wu yi ba eko natso yi gboro na               9.0
#
#    eng words count
# 0             11.0
# 1              4.0
# 2              6.0
# 3              9.0
# 4              5.0

# %%
df['eng words count'].max()
# Out:
# 321.0

# %%
df['nupe words count'].max()
# Out:
# 425.0

# %%
df=df[(df['eng words count']<320)&(df['nupe words count']<320)]

# %%
df
# Out:
#                                                       eng  \
# 0       Praise be to Allah the Cherisher and Sustainer...
# 1                             Most Gracious Most Merciful
# 2                           Master of the Day of Judgment
# 3                Thee do we worship and Thine aid we seek
# 4                                Show us the straight way
# ...                                                   ...
# 288941                I cannot find time to read the book
# 288942                  The pasture has an area of  acres
# 288943                  The fields yielded a good harvest
# 288944                            Thats the meat of a hen
# 288945                 By whom was the island discovered?
#
#                                                      nupe  nupe words count  \
# 0       Yebo kpata ajin tabbata ya Soko Etsu nae kpa a...              12.0
# 1       Estu na niimau ke ke yiba to mumini to kafiri ...              26.0
# ...

# %%
# Unique Words in Nupe
nupe_unique_words = set(df['nupe'].str.split().explode())
print("Unique Words in Nupe:", len(nupe_unique_words))

# Total Number of Unique Words
total_unique_words = len(set(df['nupe'].str.split().explode()))
print("Total Number of Unique Words:", total_unique_words)
# Out:
# Unique Words in Nupe: 35881
# Total Number of Unique Words: 35881

# %%
from sklearn.model_selection import train_test_split
train,test=train_test_split(df,test_size=0.2)

# %%
train['eng words count'].max()
# Out:
# 222.0

# %%
train['nupe words count'].max()
# Out:
# 319.0

# %%
# !pip install wordcloud matplotlib

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# Concatenate all Nupe words into a single string
nupe_text = ' '.join(df['nupe'].astype(str))

# Generate a WordCloud object
wordcloud = WordCloud(width=800, height=400, background_color='black').generate(nupe_text)

# Plot the WordCloud image
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title('Word Cloud for Nupe Words')
plt.show()

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# Concatenate all Nupe words into a single string
nupe_text = ' '.join(df['eng'].astype(str))

# Generate a WordCloud object
wordcloud = WordCloud(width=800, height=400, background_color='black').generate(nupe_text)

# Plot the WordCloud image
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title('Word Cloud for English Words')
plt.show()
